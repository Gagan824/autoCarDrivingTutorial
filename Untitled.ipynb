# %%
import pickle
from program_utils.lane_detection import *
from program_utils.distance_utils import *
from yolo.model import *
import cv2
from depth_model.frame_depth import *
from program_utils.all_confs import *
from program_utils.alert import *
import torch
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

from main import get_from_frame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# specifying the path to the model weight
model_path = 'yolo/model_weight/best.pt'
# loading model
model = load_model(model_path)
d_model = DepthModel()
# Out:
# Using cache found in C:\Users\MSI 1/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-1-30 torch 1.10.2+cu113 CUDA:0 (GeForce GTX 1650 Ti with Max-Q Design, 4096MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# Loading mono_640x192 model
# mono_640x192 model loaded

# %%
image = cv2.imread('test_images/capture_6.jpg')

# %%
image = get_from_frame(model, d_model, image)
# Out:
# Center:  (879, 453)
# Average radius:  Radius of Curvature: 19419.30 m
# Offset:  Center Offset: -0.13 m
# Direction:  forward

# %%
plt.figure(figsize=(12, 10))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
